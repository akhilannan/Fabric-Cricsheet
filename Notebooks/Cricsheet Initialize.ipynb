# %% [markdown]
# # Install Fabric Utils

# %%
# !pip install /lakehouse/default/Files/packages/fabric_utils-0.1-py3-none-any.whl -q

# %% [markdown]
# # Import Required Libraries & Enable Spark Autotune

# %%
import fabric_utils as U
from pyspark.sql import functions as F
from pyspark.sql import types as T
from pyspark.sql.window import Window
spark.conf.set("spark.ms.autotune.enabled", True)

# %% [markdown]
# # Set Constants

# %%
RAW_LAKEHOUSE = "lh_bronze"
CLEAN_LAKEHOUSE = "lh_gold"
